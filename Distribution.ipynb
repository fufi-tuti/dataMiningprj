# %% [markdown]
# <a href="https://colab.research.google.com/github/fufi-tuti/dataMiningprj/blob/main/Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_excel('/content/Student_Depression_Dataset.xlsx')

df_sample = df.sample( n=100 )
print(df_sample)
# Out:
#            id  Gender  Age         City Profession  Academic Pressure  \
# 14181   71729    Male   19     Ludhiana    Student                  2
# 2716    13830  Female   19    Ahmedabad    Student                  4
# 25412  128031    Male   27    Ghaziabad    Student                  2
# 22422  113059  Female   19     Ludhiana    Student                  5
# 12556   63526    Male   28  Vasai-Virar    Student                  4
# ...       ...     ...  ...          ...        ...                ...
# 13085   66256    Male   32     Vadodara    Student                  1
# 10         83    Male   24       Nagpur    Student                  3
# 1081     5601    Male   23     Srinagar    Student                  5
# 23878  120304    Male   28         Pune    Student                  5
# 17924   90676  Female   29       Jaipur    Student                  3
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 14181              0  8.24                   4                 0
# 2716               0  5.48                   4                 0
# 25412              0  7.88                   5                 0
# 22422              0  5.32                   5                 0
# 12556              0  5.37                   2                 0
# ...              ...   ...                 ...               ...
# 13085              0  9.84                   3                 0
# 10                 0  6.10                   3                 0
# 1081               0  7.09                   1                 0
# 23878              0  7.27                   2                 0
# 17924              0  5.52                   2                 0
#
#           Sleep Duration Dietary Habits    Degree  \
# 14181          7-8 hours        Healthy  Class 12
# 2716   More than 8 hours        Healthy  Class 12
# 25412  More than 8 hours       Moderate     B.Com
# 22422          5-6 hours      Unhealthy  Class 12
# 12556  Less than 5 hours      Unhealthy       BCA
# ...                  ...            ...       ...
# 13085          7-8 hours      Unhealthy       MCA
# 10             5-6 hours       Moderate  Class 12
# 1081           5-6 hours      Unhealthy       BHM
# 23878  More than 8 hours       Moderate       LLB
# 17924          5-6 hours      Unhealthy       MSc
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 14181                                    No                 8
# 2716                                    Yes                 8
# 25412                                    No                 2
# 22422                                   Yes                11
# 12556                                   Yes                 2
# ...                                     ...               ...
# 13085                                   Yes                12
# 10                                      Yes                11
# 1081                                    Yes                 2
# 23878                                   Yes                 7
# 17924                                    No                11
#
#        Financial Stress Family History of Mental Illness  Depression
# 14181               4.0                               No           0
# 2716                4.0                              Yes           1
# 25412               1.0                               No           0
# 22422               1.0                              Yes           1
# 12556               1.0                               No           1
# ...                 ...                              ...         ...
# 13085               4.0                              Yes           1
# 10                  1.0                              Yes           1
# 1081                3.0                              Yes           1
# 23878               1.0                              Yes           1
# 17924               4.0                               No           0
#
# [100 rows x 18 columns]

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x=df_sample["Gender"], palette="pastel")
plt.title("Distribution of Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()


plt.figure(figsize=(8, 5))
sns.countplot(x=df_sample["Profession"], palette="pastel")
plt.title("Distribution of profession")
plt.xlabel(" profession")
plt.ylabel("Count")
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-30-76e48f05821a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df_sample["Gender"], palette="pastel")
# <ipython-input-30-76e48f05821a>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df_sample["Profession"], palette="pastel")

# %%
plt.figure(figsize=(5,3))
df_sample["Age"].plot.hist(bins=20, edgecolor="black")
plt.title("Histogram of Age")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(5,3))
df_sample["CGPA"].plot.hist(bins=20, edgecolor="black")
plt.title("Histogram of CGPA")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(5,3))
df_sample["CGPA"].plot.hist(bins=20, edgecolor="black")
plt.title("Histogram of Financial Stress")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(5,3))
df_sample["Academic Pressure"].plot.hist(bins=20, edgecolor="black")
plt.title("Histogram of Academic Pressure")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(5,3))
df_sample["Study Satisfaction"].plot.hist(bins=20, edgecolor="black")
plt.title("Histogram of Study Satisfaction")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(5,3))
df_sample["Work/Study Hours"].plot.hist(bins=20, edgecolor="black")
plt.title("Histogram of Work/Study Hours")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='CGPA', y='Sleep Duration', hue=df_sample['Depression'], data=df_sample, palette="bright")
plt.title("Sleep Duration and CGPA")
plt.xlabel("CGPA")
plt.ylabel("Sleep Duration")
# Out:
# Text(0, 0.5, 'Sleep Duration')

# %%
class_counts = df_sample[df.columns[-1]].value_counts()
plt.figure(figsize=(6, 4))
class_counts.plot(kind="bar", color=["blue", "orange", "green"])
plt.title("Class Imbalance Analysis")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()
